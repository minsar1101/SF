# %%
import requests
import json
from bs4 import BeautifulSoup
import itertools
import pprint as pp
import time
from datetime import datetime
import pandas as pd

# %%
def get_car_links(url_ads_page):
    """
    Функция, получает страницу с объявлениями, возвращает - список url объявлений на этой странице
    """
    ads_list = []
    page = requests.get(url_ads_page)
    soup = BeautifulSoup(page.content, 'html.parser')
    
    if_last_page = 0

    if len(soup.find_all('a', class_='Button_disabled')) == 0:
        if_last_page = 1
    
    for el in soup.find_all('a', class_='Button_disabled'):
        if ('Следующая' in el.text) or (page.status_code == 404):
            if_last_page = 1
    
    for link in soup.find_all('a', class_='Link ListingItemTitle-module__link'):
        ads_list.append(link['href'])
        
    return ads_list, if_last_page

# %%
def parse_ad(url):
    """
    Функция - парсит необходимые данные из объявления
    Возвращает словарь с данными
    """
    page = requests.get(url)
    soup = BeautifulSoup(page.content, 'html.parser')
    script = soup.find_all('script',id = "initial-state")[0].contents[0]
    data = json.loads(script)
    
    # словарь с данными объявления
    car_dict = {'bodyType':0, 'brand':0, 'car_url': 0, 'color':0, 'complectation_dict':0, 
                'description':0, 'engineDisplacement':0, 'enginePower':0, 'equipment_dict':0,
                'fuelType':0, 'image':0, 'mileage':0,  'modelDate':0, 'model_info':0, 
                'model_name':0, 'name':0, 'numberOfDoors':0, 'parsing_unixtime':0, 'priceCurrency':0,
                'productionDate':0, 'sell_id':0, 'super_gen':0, 
                'vehicleConfiguration':0, 'vehicleTransmission':0,'vendor':0, 
                'Владельцы':0,'Владение':0, 'ПТС':0,    
                 'Привод':0, 'Руль':0,  'Состояние':0,   'Таможня':0, 'price':0}
    
    # начинаем парсить
    try: car_dict['bodyType'] = data['card']['vehicle_info']['configuration']['human_name'] 
    except: car_dict['bodyType'] = None

    try: car_dict['brand'] = data['card']['vehicle_info']['mark_info']['code']
    except: car_dict['brand'] = None

    car_dict['car_url'] = url

    try: car_dict['color'] = soup.find_all('li', class_='CardInfoRow CardInfoRow_color')[0].find('a').text
    except: car_dict['color'] = None

    try: car_dict['complectation_dict'] = data['card']['vehicle_info']['configuration']
    except: car_dict['complectation_dict'] = None

    try: car_dict['description'] = data['card']['description']
    except: car_dict['description'] = None

    try: car_dict['engineDisplacement'] = data['card']['vehicle_info']['tech_param']['human_name'].split()[0]
    except: car_dict['engineDisplacement'] = None

    try: car_dict['enginePower'] = data['card']['vehicle_info']['tech_param']['power']
    except: car_dict['enginePower'] = None

    try: car_dict['equipment_dict'] = data['card']['vehicle_info']['equipment']
    except: car_dict['equipment_dict'] = None

    try: car_dict['fuelType'] = data['card']['lk_summary'].split()[-1]
    except: car_dict['fuelType'] = None

    try: car_dict['image'] = 'http:' + data['card']['vehicle_info']['configuration']['main_photo']['sizes']['orig']
    except: car_dict['image'] = None

    try: car_dict['mileage'] = data['card']['state']['mileage']
    except: car_dict['mileage'] = None

    try: car_dict['modelDate'] = data['card']['vehicle_info']['super_gen']['year_from']
    except: car_dict['modelDate'] = None

    try: car_dict['model_info'] = data['card']['vehicle_info']['model_info']
    except: car_dict['model_info'] = None

    try: car_dict['model_name'] = data['card']['vehicle_info']['model_info']['code']
    except: car_dict['model_name'] = None

    try: car_dict['name'] =  data['card']['vehicle_info']['tech_param']['human_name']
    except: car_dict['name'] = None

    try: car_dict['numberOfDoors'] = data['card']['vehicle_info']['configuration']['doors_count']
    except: car_dict['numberOfDoors'] = None

    car_dict['parsing_unixtime'] = time.time()

    try: car_dict['priceCurrency'] = data['card']['price_info']['currency']
    except: car_dict['priceCurrency'] = None

    try: car_dict['productionDate'] = data['card']['documents']['year']
    except: car_dict['productionDate'] = None

    try: car_dict['sell_id'] = data['card']['id']
    except: car_dict['sell_id'] = None

    try: car_dict['super_gen'] = data['card']['vehicle_info']['super_gen']
    except: car_dict['super_gen'] = None

    try: car_dict['vehicleConfiguration'] = data['card']['vehicle_info']['configuration']['body_type'] + ' '\
        + data['card']['vehicle_info']['tech_param']['transmission'] + ' '\
        + data['card']['vehicle_info']['tech_param']['human_name'].split()[0]
    except: car_dict['vehicleConfiguration'] = None

    try: car_dict['vehicleTransmission'] = soup.\
        find_all('li', class_='CardInfoRow CardInfoRow_transmission')[0].find_all('span')[1].text
    except: car_dict['vehicleTransmission'] = None

    try: car_dict['vendor'] = data['card']['vehicle_info']['vendor']
    except: car_dict['vendor'] = None

    try: car_dict['Владельцы'] = soup.find_all(
        'li', class_='CardInfoRow CardInfoRow_ownersCount')[0].find_all('span')[1].text
    except: car_dict['Владельцы'] = None

    try: car_dict['Владение'] =  soup.\
        find_all('li', class_='CardInfoRow_owningTime')[0].find_all('span')[1].text
    except: car_dict['Владение'] = None

    try: car_dict['ПТС'] = soup.\
        find_all('li', class_='CardInfoRow_pts')[0].find_all('span')[1].text
    except: car_dict['ПТС'] = None

    try: car_dict['Привод'] = data['card']['lk_summary'].split(', ')[-2]
    except: car_dict['Привод'] = None

    try: car_dict['Руль'] = soup.find_all(
        'li', class_='CardInfoRow CardInfoRow_wheel')[0].find_all('span')[1].text
    except: car_dict['Руль'] = None

    try: car_dict['Состояние'] = soup.find_all(
        'li', class_='CardInfoRow CardInfoRow_state')[0].find_all('span')[1].text
    except: car_dict['Руль'] = None

    try: car_dict['Таможня'] = soup.find_all(
        'li', class_='CardInfoRow CardInfoRow_customs')[0].find_all('span')[1].text
    except: car_dict['Таможня'] = None

    try: car_dict['price'] = data['card']['price_info']['price']
    except: car_dict['price'] = None

    try: car_dict['start_date'] =  data['card']['additional_info']['hot_info']['start_time']
    except: car_dict['start_date'] = None

    try: car_dict['hidden'] =  data['card']['additional_info']['hidden']
    except: car_dict['hidden'] = None
    
    # возвращаем словарь
    return car_dict

# %%
pd.set_option('display.max_columns', None)
test = pd.read_csv('test.csv')
test[test['model_name']=='PASSAT'].sample(5)
# Out:
#               bodyType       brand  \
# 23761            седан  VOLKSWAGEN
# 26293  универсал 5 дв.  VOLKSWAGEN
# 23679            седан  VOLKSWAGEN
# 30679  универсал 5 дв.  VOLKSWAGEN
# 23737            седан  VOLKSWAGEN
#
#                                                  car_url        color  \
# 23761  https://auto.ru/cars/used/sale/volkswagen/pass...        синий
# 26293  https://auto.ru/cars/used/sale/volkswagen/pass...        серый
# 23679  https://auto.ru/cars/used/sale/volkswagen/pass...  серебристый
# 30679  https://auto.ru/cars/used/sale/volkswagen/pass...       чёрный
# 23737  https://auto.ru/cars/used/sale/volkswagen/pass...       чёрный
#
#       complectation_dict                                        description  \
# 23761                NaN  Безопасность: 6. Обзор: 3. Мультимедиа: 3. Ком...
# 26293                NaN  Доброго времени суток! Продаю VW Passat b4 уни...
# 23679                NaN  ,\nБезопасная покупка в АСЦ/ЧЕСТНО –легко! \n\...
# 30679                NaN  авто в отличном состоянии 1год из германии про...
# 23737                NaN  Один собственник\nОригинальный ПТС\nПодтвержде...
#
#       engineDisplacement enginePower  \
# 23761            1.8 LTR     152 N12
# 26293            2.0 LTR     115 N12
# 23679            1.8 LTR     152 N12
# 30679            1.6 LTR     120 N12
# 23737            1.4 LTR     150 N12
#
#                                           equipment_dict fuelType  \
# 23761  {"asr":true,"ptf":true,"airbag-driver":true,"a...   бензин
# 26293  {"electro-window-back":true,"engine-proof":tru...   бензин
# 23679                                                NaN   бензин
# 30679  {"engine-proof":true,"asr":true,"tinted-glass"...   дизель
# 23737  {"cruise-control":true,"tinted-glass":true,"es...   бензин
#
#                                                    image  mileage  modelDate  \
# 23761  https://avatars.mds.yandex.net/get-autoru-vos/...   116332       2011
# 26293  https://autoru.naydex.net/o9DBXQ270/5ac010hAY0...   340300       1993
# 23679  https://avatars.mds.yandex.net/get-autoru-vos/...   150413       2005
# 30679  https://autoru.naydex.net/cSRr96A18/708ec0RhY5...   130000       2014
# 23737  https://avatars.mds.yandex.net/get-autoru-vos/...    36051       2014
#
#                                               model_info model_name  \
# 23761  {"code":"PASSAT","name":"Passat","ru_name":"Па...     PASSAT
# 26293  {"code":"PASSAT","name":"Passat","ru_name":"Па...     PASSAT
# 23679  {"code":"PASSAT","name":"Passat","ru_name":"Па...     PASSAT
# 30679  {"code":"PASSAT","name":"Passat","ru_name":"Па...     PASSAT
# 23737  {"code":"PASSAT","name":"Passat","ru_name":"Па...     PASSAT
#
#                      name  numberOfDoors  parsing_unixtime priceCurrency  \
# 23761  1.8 AMT (152 л.с.)              4        1603215006           RUB
# 26293   2.0 MT (115 л.с.)              5        1603224623           RUB
# 23679  1.8 AMT (152 л.с.)              4        1603214695           RUB
# 30679  1.6d MT (120 л.с.)              5        1603575083           RUB
# 23737  1.4 AMT (150 л.с.)              4        1603214912           RUB
#
#        productionDate     sell_id  \
# 23761            2011  1101191135
# 26293            1996  1101220227
# 23679            2010  1101231042
# 30679            2015  1101318377
# 23737            2018  1101201871
#
#                                                super_gen  \
# 23761  {"id":"7150232","displacement":1798,"engine_ty...
# 26293  {"id":"6381424","displacement":1984,"engine_ty...
# 23679  {"id":"4553930","displacement":1798,"engine_ty...
# 30679  {"id":"20273230","displacement":1598,"engine_t...
# 23737  {"id":"20581538","displacement":1395,"engine_t...
#
#                vehicleConfiguration vehicleTransmission    vendor  \
# 23761               SEDAN ROBOT 1.8    роботизированная  EUROPEAN
# 26293  WAGON_5_DOORS MECHANICAL 2.0        механическая  EUROPEAN
# 23679               SEDAN ROBOT 1.8    роботизированная  EUROPEAN
# 30679  WAGON_5_DOORS MECHANICAL 1.6        механическая  EUROPEAN
# 23737               SEDAN ROBOT 1.4    роботизированная  EUROPEAN
#
#          Владельцы    Владение       ПТС    Привод   Руль           Состояние  \
# 23761  2 владельца         NaN  Оригинал  передний  Левый  Не требует ремонта
# 26293  3 или более         NaN  Оригинал  передний  Левый  Не требует ремонта
# 23679  3 или более         NaN  Оригинал  передний  Левый  Не требует ремонта
# 30679   1 владелец  11 месяцев  Оригинал  передний  Левый  Не требует ремонта
# 23737   1 владелец         NaN  Оригинал  передний  Левый  Не требует ремонта
#
#           Таможня
# 23761  Растаможен
# 26293  Растаможен
# 23679  Растаможен
# 30679  Растаможен
# 23737  Растаможен

# %%
# протестируем функции и сравним с тестовыми данными
ads_list = []

for url in get_car_links('https://auto.ru/moskva/cars/volkswagen/passat/all/?page=2')[0]:
    ads_list.append(parse_ad(url))
    #time.sleep(1) # На всякий случай ждем 1 секунду

# %%
df = pd.DataFrame(ads_list)
df.head()
# Out:
#   bodyType       brand                                            car_url  \
# 0    Седан  VOLKSWAGEN  https://auto.ru/cars/used/sale/volkswagen/pass...
# 1    Седан  VOLKSWAGEN  https://auto.ru/cars/used/sale/volkswagen/pass...
# 2    Седан  VOLKSWAGEN  https://auto.ru/cars/new/group/volkswagen/pass...
# 3    Седан  VOLKSWAGEN  https://auto.ru/cars/used/sale/volkswagen/pass...
# 4    Седан  VOLKSWAGEN  https://auto.ru/cars/used/sale/volkswagen/pass...
#
#     color                                 complectation_dict  \
# 0  чёрный  {'id': '2309872', 'body_type': 'SEDAN', 'doors...
# 1   белый  {'id': '20232338', 'body_type': 'SEDAN', 'door...
# 2    None  {'id': '21674468', 'body_type': 'SEDAN', 'door...
# 3   синий  {'id': '7150227', 'body_type': 'SEDAN', 'doors...
# 4   синий  {'id': '7150227', 'body_type': 'SEDAN', 'doors...
#
#                                          description engineDisplacement  \
# 0  Volkswagen Passat B6 Седан 1.6 MT (102 л.с.).О...                1.6
# 1  - Автомобиль с полным НДС!\n- Один владелец\n-...                1.4
# 2  Эксклюзивные условия в Фольксваген Центр Север...                1.4
# 3  Автомобиль в отличном состоянии. Бережная эксп...                1.8
# 4  Машина в отличном состоянии!\nПолностью обслуж...                1.8
#
#    enginePower                                     equipment_dict fuelType  \
# 0          102  {'engine-proof': True, 'cruise-control': True,...   бензин
# 1          150  {'start-button': True, 'multi-wheel': True, 'p...   бензин
# 2          150  {'asr': True, 'esp': True, 'usb': True, 'multi...   бензин
# 3          152  {'engine-proof': True, 'tinted-glass': True, '...   бензин
# 4          152                                                 {}   бензин
#
#                                                image  mileage  modelDate  \
# 0  http://avatars.mds.yandex.net/get-verba/103038...   154345       2005
# 1  http://avatars.mds.yandex.net/get-verba/787013...    41445       2014
# 2  http://avatars.mds.yandex.net/get-verba/787013...        0       2019
# 3  http://avatars.mds.yandex.net/get-verba/787013...    96000       2011
# 4  http://avatars.mds.yandex.net/get-verba/787013...    89000       2011
#
#                                           model_info model_name  \
# 0  {'code': 'PASSAT', 'name': 'Passat', 'ru_name'...     PASSAT
# 1  {'code': 'PASSAT', 'name': 'Passat', 'ru_name'...     PASSAT
# 2  {'code': 'PASSAT', 'name': 'Passat', 'ru_name'...     PASSAT
# 3  {'code': 'PASSAT', 'name': 'Passat', 'ru_name'...     PASSAT
# 4  {'code': 'PASSAT', 'name': 'Passat', 'ru_name'...     PASSAT
#
#                  name  numberOfDoors  parsing_unixtime priceCurrency  \
# 0   1.6 MT (102 л.с.)              4      1.611668e+09           RUR
# 1  1.4 AMT (150 л.с.)              4      1.611668e+09           RUR
# 2  1.4 AMT (150 л.с.)              4      1.611668e+09           RUR
# 3  1.8 AMT (152 л.с.)              4      1.611668e+09           RUR
# 4  1.8 AMT (152 л.с.)              4      1.611668e+09           RUR
#
#    productionDate     sell_id  \
# 0            2008  1102217414
# 1            2016  1102266881
# 2            2020  1101835509
# 3            2011  1102272685
# 4            2012  1101973042
#
#                                            super_gen  vehicleConfiguration  \
# 0  {'id': '2309871', 'name': 'B6', 'year_from': 2...  SEDAN MECHANICAL 1.6
# 1  {'id': '20232305', 'name': 'B8', 'year_from': ...       SEDAN ROBOT 1.4
# 2  {'id': '21674342', 'name': 'B8 Рестайлинг', 'r...       SEDAN ROBOT 1.4
# 3  {'id': '7150225', 'name': 'B7', 'year_from': 2...       SEDAN ROBOT 1.8
# 4  {'id': '7150225', 'name': 'B7', 'year_from': 2...       SEDAN ROBOT 1.8
#
#   vehicleTransmission    vendor    Владельцы             Владение       ПТС  \
# 0        механическая  EUROPEAN  3 или более  11 лет и 12 месяцев  Оригинал
# 1    роботизированная  EUROPEAN   1 владелец                 None  Оригинал
# 2                None  EUROPEAN         None                 None      None
# 3    роботизированная  EUROPEAN  3 или более                 None  Оригинал
# 4    роботизированная  EUROPEAN  2 владельца                 None  Оригинал
#
#      Привод   Руль           Состояние     Таможня      price  \
# 0  передний  Левый  Не требует ремонта  Растаможен   360000.0
# 1  передний  Левый  Не требует ремонта  Растаможен  1458000.0
# 2  передний   None                   0        None  2393000.0
# 3  передний  Левый  Не требует ремонта  Растаможен   659000.0
# 4  передний  Левый  Не требует ремонта  Растаможен   895000.0
#
#              start_date  hidden
# 0  2021-01-19T17:57:07Z   False
# 1  2021-01-25T09:58:37Z   False
# 2  2020-12-08T12:34:36Z   False
# 3  2021-01-25T18:07:48Z   False
# 4  2020-12-21T18:36:36Z   False

# %%
models_dict = {}
for brand in test['brand'].unique():
    model_list = []
    for model in test['model_name'][test['brand'] == brand].unique():
        model_list.append(model.lower())
    models_dict[brand.lower()] = model_list

# %%
models_dict.keys()
# Out:
# dict_keys(['skoda', 'audi', 'honda', 'volvo', 'bmw', 'nissan', 'infiniti', 'mercedes', 'toyota', 'lexus', 'volkswagen', 'mitsubishi'])

# %%
ads_list = []
i = 0

for brand in  models_dict.keys():
    if len(ads_list) > 0:
        print('В марку {} было добавлено {} объявлений\n\n'.format(prev_brand_name, len(ads_list)))
        backup_df = pd.DataFrame(ads_list)
        backup_df.to_csv('soup_parser/' + prev_brand_name + '_backup.csv')
        ads_list = [] # на всякий случай будем чистить для каждого бренда
    print('Start {} {}'.format(brand, datetime.now()))
    for model in models_dict[brand]:
        print('\tModel {} {}'.format(model, datetime.now()))
        ads_num = 0
        for i in itertools.count(start = 1):
            ads_page = 'https://auto.ru/moskva/cars/' + brand + '/' + model + '/all/?page=' + str(i)
            if requests.get(ads_page).status_code == 404:
                break
            #print(ads_page)
            result = get_car_links(ads_page)
            try:
                for url in result[0]:
                    ads_list.append(parse_ad(url))
            except:
                pass
                    #time.sleep(1) # На всякий случай ждем 1 секунду
            ads_num += len(result[0])
            if result[1] == 1:
                backup_df = pd.DataFrame(ads_list)
                backup_df.to_csv('soup_parser/' + brand + '_' + model + '_backup.csv')
                print('Было добавлено {} страниц и {} объявлений'.format(i, ads_num) )
                break
    df = pd.DataFrame(ads_list)
    result_df = result_df.append(df)
    result_df.to_csv(brand + '_backup.csv')
    prev_brand_name = brand
# Out:
# Start mitsubishi 2021-01-22 01:29:20.493739
# 	Model pajero_sport 2021-01-22 01:29:20.494737
# Было добавлено 6 страниц и 223 объявлений
# 	Model outlander 2021-01-22 01:31:07.137819
# Было добавлено 27 страниц и 971 объявлений
# 	Model l200 2021-01-22 01:38:41.941220
# Было добавлено 2 страниц и 50 объявлений
# 	Model montero 2021-01-22 01:39:04.492337
# Было добавлено 1 страниц и 21 объявлений
# 	Model lancer 2021-01-22 01:39:15.346655
# Было добавлено 14 страниц и 497 объявлений
# 	Model pajero 2021-01-22 01:42:48.998123
# Было добавлено 7 страниц и 225 объявлений
# 	Model montero_sport 2021-01-22 01:44:29.543922
# Было добавлено 1 страниц и 27 объявлений
# 	Model galant 2021-01-22 01:44:42.186137
# Было добавлено 3 страниц и 110 объявлений
# 	Model pajero_mini 2021-01-22 01:45:30.237552
# Было добавлено 1 страниц и 3 объявлений
# 	Model pajero_io 2021-01-22 01:45:32.425820
# Было добавлено 1 страниц и 9 объявлений
# 	Model asx 2021-01-22 01:45:37.733223
# Было добавлено 16 страниц и 566 объявлений
# 	Model colt 2021-01-22 01:49:44.091946
# Было добавлено 1 страниц и 35 объявлений
# 	Model carisma 2021-01-22 01:50:00.777104
# Было добавлено 2 страниц и 70 объявлений
# 	Model space_star 2021-01-22 01:50:31.401933
# Было добавлено 1 страниц и 21 объявлений
# 	Model pajero_pinin 2021-01-22 01:50:40.675908
# Было добавлено 1 страниц и 8 объявлений
# 	Model fto 2021-01-22 01:50:44.803167
# Было добавлено 1 страниц и 1 объявлений
# 	Model lancer_evolution 2021-01-22 01:50:46.274125
# Было добавлено 1 страниц и 15 объявлений
# 	Model grandis 2021-01-22 01:50:53.448293
# Было добавлено 1 страниц и 15 объявлений
# 	Model eclipse_cross 2021-01-22 01:51:00.381786
# Было добавлено 2 страниц и 57 объявлений
# 	Model eclipse 2021-01-22 01:51:26.939860
# Было добавлено 1 страниц и 22 объявлений
# 	Model minicab 2021-01-22 01:51:36.755771
# Было добавлено 1 страниц и 2 объявлений
# 	Model delica_d_5 2021-01-22 01:51:38.506928
# Было добавлено 1 страниц и 4 объявлений
# 	Model endeavor 2021-01-22 01:51:41.354237
# Было добавлено 1 страниц и 3 объявлений
# 	Model delica 2021-01-22 01:51:43.728859
# Было добавлено 1 страниц и 8 объявлений
# 	Model i_miev 2021-01-22 01:51:47.979854
# Было добавлено 1 страниц и 1 объявлений
# 	Model space_wagon 2021-01-22 01:51:50.006979
# Было добавлено 1 страниц и 16 объявлений
# 	Model lancer_ralliart 2021-01-22 01:51:58.456677
# Было добавлено 1 страниц и 1 объявлений
# 	Model legnum 2021-01-22 01:51:59.872884
# Было добавлено 1 страниц и 9 объявлений
# 	Model airtrek 2021-01-22 01:52:04.296085
# Было добавлено 1 страниц и 8 объявлений
# 	Model space_gear 2021-01-22 01:52:08.452169
# Было добавлено 1 страниц и 7 объявлений
# 	Model delica_d2 2021-01-22 01:52:12.276755
# Было добавлено 1 страниц и 1 объявлений
# 	Model l300 2021-01-22 01:52:13.783588
# Было добавлено 1 страниц и 3 объявлений
# 	Model sigma 2021-01-22 01:52:16.249054
# Было добавлено 1 страниц и 1 объявлений
# 	Model diamante 2021-01-22 01:52:17.846748
# Было добавлено 1 страниц и 5 объявлений
# 	Model l400 2021-01-22 01:52:20.658794
# Было добавлено 1 страниц и 1 объявлений
# 	Model mirage 2021-01-22 01:52:22.302397
# Было добавлено 1 страниц и 5 объявлений
# 	Model dingo 2021-01-22 01:52:25.189738
# Было добавлено 1 страниц и 3 объявлений
# 	Model space_runner 2021-01-22 01:52:27.588336
# Было добавлено 1 страниц и 4 объявлений
# 	Model chariot 2021-01-22 01:52:30.277178
# Было добавлено 1 страниц и 11 объявлений
# 	Model ek_wagon 2021-01-22 01:52:35.353086
# Было добавлено 1 страниц и 1 объявлений
# 	Model rvr 2021-01-22 01:52:37.103436
# Было добавлено 1 страниц и 7 объявлений
# 	Model libero 2021-01-22 01:52:41.532591
# Было добавлено 1 страниц и 5 объявлений
# 	Model dion 2021-01-22 01:52:44.613350
# Было добавлено 1 страниц и 9 объявлений
# 	Model emeraude 2021-01-22 01:52:49.044593
# Было добавлено 1 страниц и 0 объявлений
# 	Model aspire 2021-01-22 01:52:50.179165
# Было добавлено 1 страниц и 2 объявлений
# 	Model minica 2021-01-22 01:52:52.130949
# Было добавлено 1 страниц и 1 объявлений
# В марку mitsubishi было добавлено 3064 объявлений
#
#
# Start nissan 2021-01-22 01:52:53.915176
# 	Model patrol 2021-01-22 01:52:53.915176
# Было добавлено 3 страниц и 80 объявлений
# 	Model teana 2021-01-22 01:53:31.836091
# Было добавлено 7 страниц и 239 объявлений
# 	Model qashqai 2021-01-22 01:55:23.705909
# Было добавлено 29 страниц и 1075 объявлений
# 	Model avenir 2021-01-22 02:04:36.180560
# Было добавлено 1 страниц и 7 объявлений
# 	Model x_trail 2021-01-22 02:04:39.847385
# Было добавлено 29 страниц и 1046 объявлений
# 	Model murano 2021-01-22 02:12:52.088298
# Было добавлено 7 страниц и 234 объявлений
# 	Model maxima 2021-01-22 02:14:41.228935
# Было добавлено 2 страниц и 46 объявлений
# 	Model navara 2021-01-22 02:15:02.033616
# Было добавлено 1 страниц и 20 объявлений
# 	Model pathfinder 2021-01-22 02:15:11.659010
# Было добавлено 4 страниц и 119 объявлений
# 	Model note 2021-01-22 02:16:05.149972
# Было добавлено 3 страниц и 99 объявлений
# 	Model tiida 2021-01-22 02:16:49.089871
# Было добавлено 4 страниц и 122 объявлений
# 	Model juke 2021-01-22 02:17:44.161904
# Было добавлено 6 страниц и 216 объявлений
# 	Model terrano 2021-01-22 02:19:22.070903
# Было добавлено 7 страниц и 255 объявлений
# 	Model almera_classic 2021-01-22 02:21:17.940194
# Было добавлено 3 страниц и 97 объявлений
# 	Model primera 2021-01-22 02:21:59.691712
# Было добавлено 4 страниц и 140 объявлений
# 	Model skyline 2021-01-22 02:22:57.397536
# Было добавлено 1 страниц и 23 объявлений
# 	Model almera 2021-01-22 02:23:07.734733
# Было добавлено 8 страниц и 284 объявлений
# 	Model qashqai_plus_2 2021-01-22 02:25:21.376702
# Было добавлено 1 страниц и 29 объявлений
# 	Model serena 2021-01-22 02:25:36.349350
# Было добавлено 1 страниц и 23 объявлений
# 	Model ad 2021-01-22 02:25:46.435718
# Было добавлено 1 страниц и 7 объявлений
# 	Model micra 2021-01-22 02:25:50.369577
# Было добавлено 2 страниц и 39 объявлений
# 	Model leaf 2021-01-22 02:26:10.616537
# Было добавлено 2 страниц и 49 объявлений
# 	Model gt_r 2021-01-22 02:26:33.697422
# Было добавлено 1 страниц и 9 объявлений
# 	Model march 2021-01-22 02:26:38.894912
# Было добавлено 1 страниц и 13 объявлений
# 	Model sentra 2021-01-22 02:26:45.248616
# Было добавлено 1 страниц и 26 объявлений
# 	Model bluebird_sylphy 2021-01-22 02:26:57.805949
# Было добавлено 1 страниц и 3 объявлений
# 	Model presage 2021-01-22 02:27:00.480233
# Было добавлено 1 страниц и 6 объявлений
# 	Model altima 2021-01-22 02:27:03.846234
# Было добавлено 1 страниц и 4 объявлений
# 	Model np300 2021-01-22 02:27:06.573945
# Было добавлено 1 страниц и 16 объявлений
# 	Model clipper 2021-01-22 02:27:13.832172
# Было добавлено 1 страниц и 1 объявлений
# 	Model prairie 2021-01-22 02:27:15.354149
# Было добавлено 1 страниц и 1 объявлений
# 	Model almera_tino 2021-01-22 02:27:16.972907
# Было добавлено 1 страниц и 5 объявлений
# 	Model dayz 2021-01-22 02:27:20.448847
# Было добавлено 1 страниц и 5 объявлений
# 	Model fairlady_z 2021-01-22 02:27:24.137583
# Было добавлено 1 страниц и 1 объявлений
# 	Model quest 2021-01-22 02:27:26.143222
# Было добавлено 1 страниц и 0 объявлений
# 	Model silvia 2021-01-22 02:27:27.471701
# Было добавлено 1 страниц и 3 объявлений
# 	Model armada 2021-01-22 02:27:30.243294
# Было добавлено 1 страниц и 3 объявлений
# 	Model 350z 2021-01-22 02:27:32.816411
# Было добавлено 1 страниц и 3 объявлений
# 	Model nv200 2021-01-22 02:27:35.770511
# Было добавлено 1 страниц и 5 объявлений
# 	Model juke_nismo 2021-01-22 02:27:39.111657
# Было добавлено 1 страниц и 7 объявлений
# 	Model stagea 2021-01-22 02:27:43.533370
# Было добавлено 1 страниц и 3 объявлений
# 	Model 280zx 2021-01-22 02:27:45.961877
# Было добавлено 1 страниц и 0 объявлений
# 	Model elgrand 2021-01-22 02:27:47.363131
# Было добавлено 1 страниц и 5 объявлений
# 	Model 300zx 2021-01-22 02:27:50.842385
# Было добавлено 1 страниц и 1 объявлений
# 	Model cefiro 2021-01-22 02:27:52.502942
# Было добавлено 1 страниц и 11 объявлений
# 	Model president 2021-01-22 02:27:59.617496
# Было добавлено 1 страниц и 1 объявлений
# 	Model cube 2021-01-22 02:28:01.141451
# Было добавлено 1 страниц и 8 объявлений
# 	Model pulsar 2021-01-22 02:28:07.040347
# Было добавлено 1 страниц и 8 объявлений
# 	Model bluebird 2021-01-22 02:28:11.684596
# Было добавлено 1 страниц и 7 объявлений
# 	Model fuga 2021-01-22 02:28:15.547832
# Было добавлено 1 страниц и 0 объявлений
# 	Model laurel 2021-01-22 02:28:16.753869
# Было добавлено 1 страниц и 7 объявлений
# 	Model wingroad 2021-01-22 02:28:20.639302
# Было добавлено 1 страниц и 9 объявлений
# 	Model caravan_coach 2021-01-22 02:28:26.350253
# Было добавлено 1 страниц и 0 объявлений
# 	Model datsun 2021-01-22 02:28:27.601904
# Было добавлено 1 страниц и 4 объявлений
# 	Model gloria 2021-01-22 02:28:30.514682
# Было добавлено 1 страниц и 2 объявлений
# 	Model expert 2021-01-22 02:28:32.511789
# Было добавлено 1 страниц и 1 объявлений
# 	Model 100nx 2021-01-22 02:28:33.982360
# Было добавлено 1 страниц и 2 объявлений
# 	Model safari 2021-01-22 02:28:36.316271
# Было добавлено 1 страниц и 4 объявлений
# 	Model liberty 2021-01-22 02:28:39.340757
# Было добавлено 1 страниц и 4 объявлений
# 	Model cedric 2021-01-22 02:28:42.514834
# Было добавлено 1 страниц и 11 объявлений
# 	Model vanette 2021-01-22 02:28:48.346850
# Было добавлено 1 страниц и 4 объявлений
# 	Model sunny 2021-01-22 02:28:51.171363
# Было добавлено 1 страниц и 10 объявлений
# 	Model otti 2021-01-22 02:28:56.221968
# Было добавлено 1 страниц и 1 объявлений
# 	Model dayz_roox 2021-01-22 02:28:57.817263
# Было добавлено 1 страниц и 1 объявлений
# 	Model presea 2021-01-22 02:28:59.435515
# Было добавлено 1 страниц и 2 объявлений
# 	Model bassara 2021-01-22 02:29:01.520007
# Было добавлено 1 страниц и 3 объявлений
# 	Model terrano_regulus 2021-01-22 02:29:03.959487
# Было добавлено 1 страниц и 0 объявлений
# 	Model rnessa 2021-01-22 02:29:05.231593
# Было добавлено 1 страниц и 0 объявлений
# 	Model tino 2021-01-22 02:29:06.466795
# Было добавлено 1 страниц и 2 объявлений
# 	Model 200sx 2021-01-22 02:29:08.380698
# Было добавлено 1 страниц и 1 объявлений
# 	Model lafesta 2021-01-22 02:29:09.928129
# Было добавлено 1 страниц и 1 объявлений
# 	Model kix 2021-01-22 02:29:11.437091
# Было добавлено 1 страниц и 0 объявлений
# 	Model largo 2021-01-22 02:29:12.563097
# Было добавлено 1 страниц и 3 объявлений
# 	Model urvan 2021-01-22 02:29:15.267891
# Было добавлено 1 страниц и 0 объявлений
# В марку nissan было добавлено 4473 объявлений
#
#
# Start skoda 2021-01-22 02:29:17.054182
# 	Model octavia 2021-01-22 02:29:17.054182
# Было добавлено 31 страниц и 1116 объявлений
# 	Model superb 2021-01-22 02:37:44.409540
# Было добавлено 6 страниц и 202 объявлений
# 	Model octavia_rs 2021-01-22 02:39:16.294255
# Было добавлено 1 страниц и 21 объявлений
# 	Model yeti 2021-01-22 02:39:26.091630
# Было добавлено 5 страниц и 181 объявлений
# 	Model kodiaq 2021-01-22 02:40:49.970707
# Было добавлено 8 страниц и 271 объявлений
# 	Model rapid 2021-01-22 02:43:17.474434
# Было добавлено 18 страниц и 641 объявлений
# 	Model fabia 2021-01-22 02:48:04.742105
# Было добавлено 5 страниц и 172 объявлений
# 	Model roomster 2021-01-22 02:49:20.502799
# Было добавлено 1 страниц и 20 объявлений
# 	Model felicia 2021-01-22 02:49:31.886014
# Было добавлено 2 страниц и 39 объявлений
# 	Model karoq 2021-01-22 02:49:48.678074
# Было добавлено 4 страниц и 140 объявлений
# 	Model fabia_rs 2021-01-22 02:50:56.268147
# Было добавлено 1 страниц и 0 объявлений
# 	Model 120 2021-01-22 02:50:57.351143
# Было добавлено 1 страниц и 1 объявлений
# 	Model 100_series 2021-01-22 02:50:58.637288
# Было добавлено 1 страниц и 1 объявлений
# 	Model favorit 2021-01-22 02:50:59.887941
# Было добавлено 1 страниц и 3 объявлений
# 	Model popular 2021-01-22 02:51:01.894127
# Было добавлено 1 страниц и 0 объявлений
# В марку skoda было добавлено 2808 объявлений
#
#
# Start toyota 2021-01-22 02:51:03.672288
# 	Model camry 2021-01-22 02:51:03.672288
# Было добавлено 17 страниц и 604 объявлений
# 	Model rav_4 2021-01-22 02:55:39.989636
# Было добавлено 10 страниц и 358 объявлений
# 	Model avensis 2021-01-22 02:58:22.780517
# Было добавлено 3 страниц и 87 объявлений
# 	Model gt86 2021-01-22 02:59:11.642644
# Было добавлено 1 страниц и 2 объявлений
# 	Model land_cruiser 2021-01-22 02:59:13.550279
# Было добавлено 12 страниц и 444 объявлений
# 	Model corolla 2021-01-22 03:02:34.817437
# Было добавлено 9 страниц и 304 объявлений
# 	Model land_cruiser_prado 2021-01-22 03:04:50.197542
# Было добавлено 9 страниц и 332 объявлений
# 	Model matrix 2021-01-22 03:07:25.908275
# Было добавлено 1 страниц и 3 объявлений
# 	Model 4runner 2021-01-22 03:07:28.233040
# Было добавлено 1 страниц и 13 объявлений
# 	Model sequoia 2021-01-22 03:07:35.825302
# Было добавлено 1 страниц и 17 объявлений
# 	Model highlander 2021-01-22 03:07:44.006244
# Было добавлено 2 страниц и 75 объявлений
# 	Model crown 2021-01-22 03:08:19.379217
# Было добавлено 1 страниц и 18 объявлений
# 	Model hilux 2021-01-22 03:08:27.767188
# Было добавлено 1 страниц и 31 объявлений
# 	Model hilux_surf 2021-01-22 03:08:42.633759
# Было добавлено 1 страниц и 5 объявлений
# 	Model isis 2021-01-22 03:08:45.827661
# Было добавлено 1 страниц и 1 объявлений
# 	Model auris 2021-01-22 03:08:47.395843
# Было добавлено 2 страниц и 47 объявлений
# 	Model vitz 2021-01-22 03:09:09.733236
# Было добавлено 1 страниц и 9 объявлений
# 	Model prius 2021-01-22 03:09:14.320354
# Было добавлено 1 страниц и 30 объявлений
# 	Model yaris 2021-01-22 03:09:27.709972
# Было добавлено 1 страниц и 30 объявлений
# 	Model carina 2021-01-22 03:09:41.608277
# Было добавлено 1 страниц и 14 объявлений
# 	Model chaser 2021-01-22 03:09:49.752184
# Было добавлено 1 страниц и 20 объявлений
# 	Model estima 2021-01-22 03:09:58.186180
# Было добавлено 1 страниц и 6 объявлений
# 	Model esquire 2021-01-22 03:10:01.727805
# Было добавлено 1 страниц и 2 объявлений
# 	Model verso 2021-01-22 03:10:03.550659
# Было добавлено 1 страниц и 13 объявлений
# 	Model echo 2021-01-22 03:10:09.740173
# Было добавлено 1 страниц и 5 объявлений
# 	Model town_ace 2021-01-22 03:10:12.757184
# Было добавлено 1 страниц и 15 объявлений
# 	Model fj_cruiser 2021-01-22 03:10:20.282773
# Было добавлено 1 страниц и 6 объявлений
# 	Model venza 2021-01-22 03:10:24.356285
# Было добавлено 1 страниц и 9 объявлений
# 	Model tundra 2021-01-22 03:10:29.079291
# Было добавлено 1 страниц и 31 объявлений
# 	Model sienna 2021-01-22 03:10:45.490164
# Было добавлено 1 страниц и 35 объявлений
# 	Model bb 2021-01-22 03:11:02.497241
# Было добавлено 1 страниц и 4 объявлений
# 	Model aqua 2021-01-22 03:11:04.951120
# Было добавлено 1 страниц и 6 объявлений
# 	Model iq 2021-01-22 03:11:08.425310
# Было добавлено 1 страниц и 1 объявлений
# 	Model caldina 2021-01-22 03:11:09.832182
# Было добавлено 1 страниц и 18 объявлений
# 	Model fortuner 2021-01-22 03:11:19.999085
# Было добавлено 1 страниц и 16 объявлений
# 	Model alphard 2021-01-22 03:11:28.046234
# Было добавлено 1 страниц и 28 объявлений
# 	Model supra 2021-01-22 03:11:41.310512
# Было добавлено 1 страниц и 5 объявлений
# 	Model c_hr 2021-01-22 03:11:45.220991
# Было добавлено 1 страниц и 6 объявлений
# 	Model mark_ii 2021-01-22 03:11:49.209530
# Было добавлено 2 страниц и 55 объявлений
# 	Model celica 2021-01-22 03:12:14.345214
# Было добавлено 1 страниц и 25 объявлений
# 	Model soarer 2021-01-22 03:12:26.203480
# Было добавлено 1 страниц и 2 объявлений
# 	Model sera 2021-01-22 03:12:28.188566
# Было добавлено 1 страниц и 2 объявлений
# 	Model mark_x 2021-01-22 03:12:29.936889
# Было добавлено 1 страниц и 4 объявлений
# 	Model sprinter_trueno 2021-01-22 03:12:32.521059
# Было добавлено 1 страниц и 7 объявлений
# 	Model camry_solara 2021-01-22 03:12:36.368858
# Было добавлено 1 страниц и 1 объявлений
# 	Model voxy 2021-01-22 03:12:37.847809
# Было добавлено 1 страниц и 7 объявлений
# 	Model crown_majesta 2021-01-22 03:12:42.193500
# Было добавлено 1 страниц и 1 объявлений
# 	Model altezza 2021-01-22 03:12:43.993766
# Было добавлено 1 страниц и 13 объявлений
# 	Model mr2 2021-01-22 03:12:50.393255
# Было добавлено 1 страниц и 5 объявлений
# 	Model avensis_verso 2021-01-22 03:12:53.459232
# Было добавлено 1 страниц и 5 объявлений
# 	Model aristo 2021-01-22 03:12:56.430940
# Было добавлено 1 страниц и 5 объявлений
# 	Model harrier 2021-01-22 03:12:59.396620
# Было добавлено 1 страниц и 7 объявлений
# 	Model hiace 2021-01-22 03:13:03.033760
# Было добавлено 1 страниц и 33 объявлений
# 	Model verso_s 2021-01-22 03:13:17.399901
# Было добавлено 1 страниц и 0 объявлений
# 	Model vellfire 2021-01-22 03:13:18.407921
# Было добавлено 1 страниц и 2 объявлений
# 	Model corolla_verso 2021-01-22 03:13:20.003195
# Было добавлено 1 страниц и 6 объявлений
# 	Model regius 2021-01-22 03:13:23.615525
# Было добавлено 1 страниц и 1 объявлений
# 	Model ipsum 2021-01-22 03:13:24.892135
# Было добавлено 1 страниц и 6 объявлений
# 	Model cresta 2021-01-22 03:13:28.256159
# Было добавлено 1 страниц и 13 объявлений
# 	Model mr_s 2021-01-22 03:13:34.259609
# Было добавлено 1 страниц и 1 объявлений
# 	Model yaris_verso 2021-01-22 03:13:35.833828
# Было добавлено 1 страниц и 0 объявлений
# 	Model noah 2021-01-22 03:13:36.823688
# Было добавлено 1 страниц и 9 объявлений
# 	Model lite_ace 2021-01-22 03:13:41.347143
# Было добавлено 1 страниц и 7 объявлений
# 	Model blade 2021-01-22 03:13:45.708988
# Было добавлено 1 страниц и 2 объявлений
# 	Model picnic 2021-01-22 03:13:47.390241
# Было добавлено 1 страниц и 2 объявлений
# 	Model corolla_spacio 2021-01-22 03:13:49.176444
# Было добавлено 1 страниц и 6 объявлений
# 	Model carina_ed 2021-01-22 03:13:53.230469
# Было добавлено 1 страниц и 1 объявлений
# 	Model corolla_levin 2021-01-22 03:13:54.553192
# Было добавлено 1 страниц и 11 объявлений
# 	Model corolla_rumion 2021-01-22 03:13:59.697628
# Было добавлено 1 страниц и 4 объявлений
# 	Model grand_hiace 2021-01-22 03:14:02.322352
# Было добавлено 1 страниц и 1 объявлений
# 	Model carina_e 2021-01-22 03:14:03.686314
# Было добавлено 1 страниц и 21 объявлений
# 	Model origin 2021-01-22 03:14:12.231008
# Было добавлено 1 страниц и 0 объявлений
# 	Model aygo 2021-01-22 03:14:13.427853
# Было добавлено 1 страниц и 0 объявлений
# 	Model starlet 2021-01-22 03:14:14.439480
# Было добавлено 1 страниц и 7 объявлений
# 	Model vanguard 2021-01-22 03:14:18.398059
# Было добавлено 1 страниц и 2 объявлений
# 	Model wish 2021-01-22 03:14:20.183507
# Было добавлено 1 страниц и 1 объявлений
# 	Model probox 2021-01-22 03:14:21.768268
# Было добавлено 1 страниц и 2 объявлений
# 	Model curren 2021-01-22 03:14:23.430821
# Было добавлено 1 страниц и 0 объявлений
# 	Model verossa 2021-01-22 03:14:24.679492
# Было добавлено 1 страниц и 4 объявлений
# 	Model sienta 2021-01-22 03:14:27.311618
# Было добавлено 1 страниц и 2 объявлений
# 	Model scepter_sedan 2021-01-22 03:14:29.058079
# Было добавлено 1 страниц и 0 объявлений
# 	Model funcargo 2021-01-22 03:14:30.033469
# Было добавлено 1 страниц и 2 объявлений
# 	Model progres 2021-01-22 03:14:31.881526
# Было добавлено 1 страниц и 2 объявлений
# 	Model passo 2021-01-22 03:14:33.794431
# Было добавлено 1 страниц и 4 объявлений
# 	Model opa 2021-01-22 03:14:36.540113
# Было добавлено 1 страниц и 2 объявлений
# 	Model sparky 2021-01-22 03:14:38.282507
# Было добавлено 1 страниц и 1 объявлений
# 	Model succeed 2021-01-22 03:14:39.692743
# Было добавлено 1 страниц и 5 объявлений
# 	Model premio 2021-01-22 03:14:43.114164
# Было добавлено 1 страниц и 1 объявлений
# 	Model previa 2021-01-22 03:14:44.682563
# Было добавлено 1 страниц и 6 объявлений
# 	Model windom 2021-01-22 03:14:48.351307
# Было добавлено 1 страниц и 4 объявлений
# 	Model allex 2021-01-22 03:14:51.008709
# Было добавлено 1 страниц и 1 объявлений
# 	Model corona 2021-01-22 03:14:52.792965
# Было добавлено 1 страниц и 9 объявлений
# 	Model sprinter_carib 2021-01-22 03:14:57.078661
# Было добавлено 1 страниц и 1 объявлений
# 	Model spade 2021-01-22 03:14:58.896911
# Было добавлено 1 страниц и 1 объявлений
# 	Model avalon 2021-01-22 03:15:00.277221
# Было добавлено 1 страниц и 2 объявлений
# 	Model tercel 2021-01-22 03:15:03.167372
# Было добавлено 1 страниц и 1 объявлений
# 	Model cynos 2021-01-22 03:15:04.680325
# Было добавлено 1 страниц и 1 объявлений
# 	Model prius_alpha 2021-01-22 03:15:06.169342
# Было добавлено 1 страниц и 5 объявлений
# 	Model sprinter 2021-01-22 03:15:09.203321
# Было добавлено 1 страниц и 4 объявлений
# 	Model master_ace_surf 2021-01-22 03:15:11.882192
# Было добавлено 1 страниц и 3 объявлений
# 	Model sprinter_marino 2021-01-22 03:15:14.283767
# Было добавлено 1 страниц и 2 объявлений
# 	Model cami 2021-01-22 03:15:16.333414
# Было добавлено 1 страниц и 8 объявлений
# 	Model corolla_ii 2021-01-22 03:15:20.799742
# Было добавлено 1 страниц и 0 объявлений
# 	Model corsa 2021-01-22 03:15:21.800628
# Было добавлено 1 страниц и 5 объявлений
# 	Model raum 2021-01-22 03:15:24.949246
# Было добавлено 1 страниц и 4 объявлений
# 	Model vista 2021-01-22 03:15:27.539392
# Было добавлено 1 страниц и 6 объявлений
# 	Model corona_exiv 2021-01-22 03:15:30.791356
# Было добавлено 1 страниц и 1 объявлений
# 	Model mega_cruiser 2021-01-22 03:15:32.519738
# Было добавлено 1 страниц и 2 объявлений
# 	Model mark_x_zio 2021-01-22 03:15:34.491667
# Было добавлено 1 страниц и 0 объявлений
# 	Model priusplus 2021-01-22 03:15:35.661540
# Было добавлено 1 страниц и 4 объявлений
# 	Model ist 2021-01-22 03:15:38.533854
# Было добавлено 1 страниц и 2 объявлений
# 	Model granvia 2021-01-22 03:15:40.794808
# Было добавлено 1 страниц и 0 объявлений
# 	Model gaia 2021-01-22 03:15:42.105427
# Было добавлено 1 страниц и 1 объявлений
# 	Model cavalier 2021-01-22 03:15:43.577489
# Было добавлено 1 страниц и 2 объявлений
# 	Model duet 2021-01-22 03:15:45.351742
# Было добавлено 1 страниц и 1 объявлений
# 	Model ractis 2021-01-22 03:15:46.714738
# Было добавлено 1 страниц и 1 объявлений
# 	Model nadia 2021-01-22 03:15:48.339392
# Было добавлено 1 страниц и 1 объявлений
# 	Model porte 2021-01-22 03:15:49.951079
# Было добавлено 1 страниц и 1 объявлений
# 	Model will_cypha 2021-01-22 03:15:51.348849
# Было добавлено 1 страниц и 0 объявлений
# 	Model paseo 2021-01-22 03:15:52.352737
# Было добавлено 1 страниц и 0 объявлений
# 	Model will 2021-01-22 03:15:53.497751
# Было добавлено 1 страниц и 1 объявлений
# 	Model platz 2021-01-22 03:15:55.672955
# Было добавлено 1 страниц и 1 объявлений
# В марку toyota было добавлено 3031 объявлений
#
#
# Start volkswagen 2021-01-22 03:15:57.414806
# 	Model touareg 2021-01-22 03:15:57.414806
# Было добавлено 12 страниц и 430 объявлений
# 	Model tiguan 2021-01-22 03:19:12.983614
# Было добавлено 26 страниц и 935 объявлений
# 	Model passat 2021-01-22 03:26:44.651185
# Было добавлено 20 страниц и 740 объявлений
# 	Model amarok 2021-01-22 03:32:13.626141
# Было добавлено 1 страниц и 32 объявлений
# 	Model polo 2021-01-22 03:32:28.378085
# Было добавлено 40 страниц и 1455 объявлений
# 	Model caddy 2021-01-22 03:43:37.431646
# Было добавлено 3 страниц и 111 объявлений
# 	Model passat_cc 2021-01-22 03:44:27.700868
# Было добавлено 3 страниц и 105 объявлений
# 	Model jetta 2021-01-22 03:45:15.878763
# Было добавлено 10 страниц и 366 объявлений
# 	Model transporter 2021-01-22 03:48:05.697815
# Было добавлено 5 страниц и 166 объявлений
# 	Model scirocco 2021-01-22 03:49:18.959612
# Было добавлено 1 страниц и 17 объявлений
# 	Model golf 2021-01-22 03:49:27.373556
# Было добавлено 10 страниц и 349 объявлений
# 	Model touran 2021-01-22 03:51:59.901439
# Было добавлено 2 страниц и 50 объявлений
# 	Model caravelle 2021-01-22 03:52:23.839445
# Было добавлено 7 страниц и 225 объявлений
# 	Model multivan 2021-01-22 03:54:09.038700
# Было добавлено 6 страниц и 197 объявлений
# 	Model sharan 2021-01-22 03:55:41.781050
# Было добавлено 2 страниц и 47 объявлений
# 	Model golf_plus 2021-01-22 03:56:03.092495
# Было добавлено 2 страниц и 51 объявлений
# 	Model teramont 2021-01-22 03:56:27.795784
# Было добавлено 1 страниц и 14 объявлений
# 	Model vento 2021-01-22 03:56:35.103754
# Было добавлено 1 страниц и 10 объявлений
# 	Model arteon 2021-01-22 03:56:40.077313
# Было добавлено 1 страниц и 0 объявлений
# 	Model phaeton 2021-01-22 03:56:41.381827
# Было добавлено 1 страниц и 7 объявлений
# 	Model golf_gti 2021-01-22 03:56:45.969716
# Было добавлено 1 страниц и 20 объявлений
# 	Model beetle 2021-01-22 03:56:55.635280
# Было добавлено 1 страниц и 16 объявлений
# 	Model eurovan 2021-01-22 03:57:03.506226
# Было добавлено 1 страниц и 4 объявлений
# 	Model california 2021-01-22 03:57:06.551081
# Было добавлено 1 страниц и 2 объявлений
# 	Model golf_r 2021-01-22 03:57:08.730252
# Было добавлено 1 страниц и 5 объявлений
# 	Model corrado 2021-01-22 03:57:12.369516
# Было добавлено 1 страниц и 1 объявлений
# 	Model golf_r32 2021-01-22 03:57:14.071963
# Было добавлено 1 страниц и 1 объявлений
# 	Model eos 2021-01-22 03:57:15.787373
# Было добавлено 1 страниц и 1 объявлений
# 	Model bora 2021-01-22 03:57:17.495804
# Было добавлено 1 страниц и 34 объявлений
# 	Model polo_gti 2021-01-22 03:57:32.558529
# Было добавлено 1 страниц и 1 объявлений
# 	Model lupo 2021-01-22 03:57:34.238065
# Было добавлено 1 страниц и 6 объявлений
# 	Model type_1 2021-01-22 03:57:37.889831
# Было добавлено 1 страниц и 3 объявлений
# 	Model pointer 2021-01-22 03:57:41.054901
# Было добавлено 1 страниц и 9 объявлений
# 	Model fox 2021-01-22 03:57:45.816678
# Было добавлено 1 страниц и 2 объявлений
# 	Model taro 2021-01-22 03:57:47.952067
# Было добавлено 1 страниц и 0 объявлений
# 	Model atlas 2021-01-22 03:57:49.277556
# Было добавлено 1 страниц и 0 объявлений
# В марку volkswagen было добавлено 5412 объявлений
#
#
# Start volvo 2021-01-22 03:57:51.686111
# 	Model v60_cross_country 2021-01-22 03:57:51.686111
# Было добавлено 1 страниц и 12 объявлений
# 	Model xc40 2021-01-22 03:57:57.968844
# Было добавлено 2 страниц и 53 объявлений
# 	Model xc60 2021-01-22 03:58:27.155243
# Было добавлено 12 страниц и 435 объявлений
# 	Model c30 2021-01-22 04:01:48.524688
# Было добавлено 1 страниц и 23 объявлений
# 	Model v50 2021-01-22 04:01:58.804624
# Было добавлено 1 страниц и 3 объявлений
# 	Model xc90 2021-01-22 04:02:01.143473
# Было добавлено 9 страниц и 330 объявлений
# 	Model v90_cross_country 2021-01-22 04:04:52.801319
# Было добавлено 1 страниц и 17 объявлений
# 	Model s60 2021-01-22 04:05:01.753476
# Было добавлено 4 страниц и 143 объявлений
# 	Model xc70 2021-01-22 04:06:06.209528
# Было добавлено 3 страниц и 88 объявлений
# 	Model v40_cc 2021-01-22 04:06:48.789014
# Было добавлено 1 страниц и 30 объявлений
# 	Model s40 2021-01-22 04:07:03.421296
# Было добавлено 3 страниц и 80 объявлений
# 	Model s90 2021-01-22 04:07:38.883017
# Было добавлено 1 страниц и 23 объявлений
# 	Model v40 2021-01-22 04:07:49.831391
# Было добавлено 1 страниц и 8 объявлений
# 	Model 240_series 2021-01-22 04:07:53.873295
# Было добавлено 1 страниц и 11 объявлений
# 	Model s80 2021-01-22 04:07:58.920039
# Было добавлено 3 страниц и 110 объявлений
# 	Model v70 2021-01-22 04:08:49.756235
# Было добавлено 1 страниц и 14 объявлений
# 	Model s60_cross_country 2021-01-22 04:08:56.152230
# Было добавлено 1 страниц и 1 объявлений
# 	Model 940 2021-01-22 04:08:57.733891
# Было добавлено 1 страниц и 19 объявлений
# 	Model 740 2021-01-22 04:09:05.891274
# Было добавлено 1 страниц и 12 объявлений
# 	Model 850 2021-01-22 04:09:11.318227
# Было добавлено 1 страниц и 22 объявлений
# 	Model v60 2021-01-22 04:09:23.417173
# Было добавлено 1 страниц и 3 объявлений
# 	Model s70 2021-01-22 04:09:25.864009
# Было добавлено 1 страниц и 9 объявлений
# 	Model c70 2021-01-22 04:09:30.451169
# Было добавлено 1 страниц и 11 объявлений
# 	Model 760 2021-01-22 04:09:35.710280
# Было добавлено 1 страниц и 4 объявлений
# 	Model 960 2021-01-22 04:09:38.322030
# Было добавлено 1 страниц и 10 объявлений
# 	Model 460 2021-01-22 04:09:44.075122
# Было добавлено 1 страниц и 11 объявлений
# 	Model 440 2021-01-22 04:09:48.995053
# Было добавлено 1 страниц и 0 объявлений
# 	Model 140 2021-01-22 04:09:50.344989
# Было добавлено 1 страниц и 0 объявлений
# В марку volvo было добавлено 1465 объявлений
#
#
# Start bb 2021-01-22 04:09:51.831522
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-fd7651aad738> in <module>
#       9         ads_list = [] # на всякий случай будем чистить для каждого бренда
#      10     print('Start {} {}'.format(brand, datetime.now()))
# ---> 11     for model in models_dict[brand]:
#      12         print('\tModel {} {}'.format(model, datetime.now()))
#      13         ads_num = 0
#
# KeyError: 'bb'
